# %%
import matplotlib.pyplot as plt

# %%
from numpy import genfromtxt
data = genfromtxt('experiment/testtrace1625659684_trainingdata.csv', delimiter=';')
cum_rewards = data[3:,1]
mean_rewards = data[3:,3]

# %%
plt.plot(cum_rewards)
plt.xlabel("Epoch")
plt.ylabel("Cumulative reward")
plt.savefig('results/td_situative_cum_reward.png')

# %%
plt.plot(mean_rewards)
plt.xlabel("Epoch")
plt.ylabel("Cumulative reward")
plt.savefig('results/td_situative_cum_reward.png')
